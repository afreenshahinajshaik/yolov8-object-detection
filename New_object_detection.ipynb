# %%
# !nvidia-smi
# Out:
# Sun Jun 29 14:26:09 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics roboflow --quiet

# %%
# !pip uninstall -y pillow-heif
# Removed explicit pillow-heif installation to avoid version conflicts
# !pip install pillow-heif==0.12.0
# Out:
# Found existing installation: pillow-heif 0.12.0
# Uninstalling pillow-heif-0.12.0:
#   Successfully uninstalled pillow-heif-0.12.0
# ...
#   Using cached pillow_heif-0.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# ...
# Using cached pillow_heif-0.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.4 MB)
# ...

# %%
# Removed redundant roboflow installation
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="nGm4OZ32DpRXI6qG5NLj")
project = rf.workspace("hanish-venkat-mtrl7").project("car_model_detection-nha2n")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.3.160, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to Car_model_detection-1 in yolov8:: 100%|██████████| 428/428 [00:00<00:00, 2062.76it/s]

# %% [markdown]
# Installing the packages related to object detection

# %%
# !pip install IPython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.8 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 918, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {list(MODES)}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.11/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are ['export', 'track', 'benchmark', 'val', 'train', 'predict'].
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ['obb', 'segment', 'detect', 'classify', 'pose']
#                 MODE (required) is one of ['export', 'track', 'benchmark', 'val', 'train', 'predict']
# ...

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/content/Car_model_detection-1/data.yaml" epochs=100 imgsz=800
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 111MB/s]
# Ultralytics 8.3.160 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data={"/content/Car_model_detection-1"}/data.yaml
# Out:
# Ultralytics 8.3.160 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,129,067 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1448.6±620.1 MB/s, size: 48.7 KB)
# val: Scanning /content/Car_model_detection-1/valid/labels.cache... 9 images, 0 backgrounds, 0 corrupt: 100% 9/9 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.16it/s]
#                    all          9          9      0.657      0.933      0.954       0.62
#           Mobile_phone          1          1      0.556          1      0.995      0.597
#                SUV_car          1          1      0.213          1      0.995      0.995
#              Sedan_car          3          3      0.874      0.667      0.789      0.621
#                    bat          3          3      0.823          1      0.995      0.389
# ...

# %%
# !yolo task=detect mode=predict  model=/content/runs/detect/train/weights/best.pt conf=0.50 source="/content/aeroplane1.jpeg"
# Out:
# Ultralytics 8.3.160 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,129,067 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/1 /content/aeroplane1.jpeg: 544x800 1 flight, 41.8ms
# Speed: 4.7ms preprocess, 41.8ms inference, 166.9ms postprocess per image at shape (1, 3, 544, 800)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
